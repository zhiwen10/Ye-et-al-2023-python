# %% [markdown]
# # figure6_task
#
# Python translation of `figure6_task.m` from Ye et al. 2023 (spirals). Visual-motor behavior task: main figure (saved under Fig5 folder names, as in the MATLAB script) and Extended Data Figs. 14-15.

# %%
from pathlib import Path

import matplotlib.pyplot as plt

DATA_FOLDER = Path(r"D:\data")
FIGURE_FOLDER = DATA_FOLDER / "figures"

# %% [markdown]
# ## Figure 5 (task)

# %%
save_folder = FIGURE_FOLDER / "Fig6"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.task.plots.plotCorrectMapsFlow import plotCorrectMapsFlow

# plot mean widefield map in correct trials
plotCorrectMapsFlow(DATA_FOLDER, save_folder)
plt.show()
# Out:
# frame 100/141

# %%
from spirals_py.task.plots.getMeanSpiralsDetection import getMeanSpiralsDetection

# mean spirals detection
getMeanSpiralsDetection(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotCorrectMeanTrace2 import plotCorrectMeanTrace2

# plot mean traces in correct trials
plotCorrectMeanTrace2(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotCorrectSpiralDensity import plotCorrectSpiralDensity

# plot spiral density maps before and after onset
plotCorrectSpiralDensity(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotSpiralRateAll import plotSpiralRateAll

# plot spiral rate change around onset time
plotSpiralRateAll(DATA_FOLDER, save_folder)
plt.show()
# Out:
# plotSpiralRateAll: half-spiral pre vs post p=[0.007  0.1993 0.1482], full-spiral pre vs post p=[0.0435 0.3329 0.68  ]

# %%
from spirals_py.task.plots.plotMeanTraceExampleSlow import plotMeanTraceExampleSlow

# plot mean traces between 0.05-2Hz
plotMeanTraceExampleSlow(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotTraceExample2_8Hz import plotTraceExample2_8Hz

# plot mean traces between 2-8Hz
plotTraceExample2_8Hz(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotHitRateSlow import plotHitRateSlow

# psychometric curve with pre-stim 0.05-2Hz power
plotHitRateSlow(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotHitRate2_8Hz import plotHitRate2_8Hz

# psychometric curve with pre-stim 2-8Hz phase
plotHitRate2_8Hz(DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Extended Data Fig. 14

# %%
save_folder = FIGURE_FOLDER / "FigS14"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.task.plots.plotPsychometricCurve import plotPsychometricCurve

# plot psychometric curve
plotPsychometricCurve(DATA_FOLDER, save_folder)
plt.show()
# Out:
# plotPsychometricCurve: 100% vs 6% left-choice p=0.001601, reaction-time p=0.03864

# %%
from spirals_py.task.plots.plotTaskSessionEpochExample import plotTaskSessionEpochExample

# plot example session with low-arousal states and miss
plotTaskSessionEpochExample(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotMeanTraceAcrossContrasts import plotMeanTraceAcrossContrasts

# plot mean responses across contrasts
plotMeanTraceAcrossContrasts(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotExamplePhase2_8Hz import plotExamplePhase2_8Hz

# plot example 2-8Hz around onset
plotExamplePhase2_8Hz(DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Extended Data Fig. 15

# %%
save_folder = FIGURE_FOLDER / "FigS15"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.task.plots.plotMeanMapsAll import plotMeanMapsAll

# plot mean wf maps in different trial types
plotMeanMapsAll(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotMeanTraceAll import plotMeanTraceAll

# plot traces in different trial types
plotMeanTraceAll(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotSpiralTrialExample import plotSpiralTrialExample

# plot single trial maps
plotSpiralTrialExample(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotPassiveSpiralPrePost import plotPassiveSpiralPrePost

# plot spiral density maps in passive viewing
plotPassiveSpiralPrePost(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotCorrectSpiralPrePost import plotCorrectSpiralPrePost

# plot spiral density maps in active task
plotCorrectSpiralPrePost(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.task.plots.plotSpiralCountOverTime import plotSpiralCountOverTime

# plot spiral density maps across radius in task
plotSpiralCountOverTime(DATA_FOLDER, save_folder)
plt.show()
