# %% [markdown]
# # figure3_sprials_mirror
#
# Python translation of `figure3_sprials_mirror.m` from Ye et al. 2023 (spirals). Main Fig. 3 (mirror-symmetric spiral decomposition) and Extended Data Fig. 11.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

DATA_FOLDER = Path(r"D:\data")
FIGURE_FOLDER = DATA_FOLDER / "figures"

# load session table
T = pd.read_excel(DATA_FOLDER / "tables" / "spiralSessions3.xlsx")
T
# Out:
#      MouseID           genotype       date  folder    rf_date  rf_folder  \
# 0   ZYE_0052   Ai210,php.eb-cre 2021-12-18       2 2021-12-18          2
# 1   ZYE_0056   Ai210,php.eb-cre 2022-01-10       1 2022-01-10          1
# 2   ZYE_0058   Ai210,php.eb-cre 2022-03-09       1 2022-03-09          1
# 3   ZYE_0059   Ai210,php.eb-cre 2022-03-14       1 2022-03-14          1
# 4   ZYE_0060   Ai210,php.eb-cre 2022-03-23       2 2022-03-23          2
# 5    AB_0004  Ai210,php.eb-flpO 2021-03-30       1 2021-03-29          2
# 6   ZYE_0012  Ai210,php.eb-flpO 2020-10-16       5 2020-10-16          1
# 7   ZYE_0062   Ai210,php.eb-cre 2022-03-29       1 2022-03-29          1
# 8   ZYE_0043   Ai210,php.eb-cre 2021-09-13       1 2021-09-13          1
# 9    LK_0001          40 uL g7s 2021-04-07       1 2021-03-08          1
# 10   LK_0003       Ai210 triple 2021-04-06       1 2021-03-31          1
# 11  ZYE_0067           soma-g8m 2022-10-23       2 2022-10-23          2
# ...

# %% [markdown]
# ## Figure 3

# %%
save_folder = FIGURE_FOLDER / "Fig3"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals_mirror.plots.plotCortexDivision import plotCortexDivision

# plot division (AP, hemi)
plotCortexDivision(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals_mirror.plots.plotVarianceExplained import plotVarianceExplained

# plot variance explained from regression
plotVarianceExplained(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals_mirror.plots.plotExampleKernelHEMI import plotExampleKernelHEMI

# plot example hemi regression kernel
plotExampleKernelHEMI(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals_mirror.plots.plotExampleKernelAP import plotExampleKernelAP

# plot example AP regression kernel
plotExampleKernelAP(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals_mirror.plots.plotKernelMapsHEMI import plotKernelMapsHEMI

# plot hemi kernel maps
plotKernelMapsHEMI(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals_mirror.plots.plotKernelMapsAP import plotKernelMapsAP

# plot AP kernel maps
plotKernelMapsAP(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals_mirror.plots.plotMatchingIndexHEMI import plotMatchingIndexHEMI

# plot hemi matching index
plotMatchingIndexHEMI(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals_mirror.plots.plotMatchingIndexAP import plotMatchingIndexAP

# plot AP matching index
plotMatchingIndexAP(DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Extended Data Fig. 11

# %%
save_folder = FIGURE_FOLDER / "FigS11"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals_mirror.plots.plotMapsSession import plotMapsSession

# plot kernel maps across sessions
plotMapsSession(T, DATA_FOLDER, save_folder)
plt.show()
