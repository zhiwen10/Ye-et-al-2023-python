# %% [markdown]
# # figure1_spirals
#
# Python translation of `figure1_spirals.m` from Ye et al. 2023 (spirals). Covers main Fig. 1 and Extended Data Figs. 1-9.

# %%
from pathlib import Path

import matplotlib.pyplot as plt

from spirals_py.utils.paths import data_root, out_root
import pandas as pd

DATA_FOLDER = data_root()  # MATLAB data release (SPIRALS_DATA_ROOT overrides)
FIGURE_FOLDER = out_root() / "figures"  # figures also go to the python tree

# load session table
T = pd.read_excel(DATA_FOLDER / "tables" / "spiralSessions3.xlsx")
T
# Out:
#      MouseID           genotype       date  folder    rf_date  rf_folder  \
# 0   ZYE_0052   Ai210,php.eb-cre 2021-12-18       2 2021-12-18          2
# 1   ZYE_0056   Ai210,php.eb-cre 2022-01-10       1 2022-01-10          1
# 2   ZYE_0058   Ai210,php.eb-cre 2022-03-09       1 2022-03-09          1
# 3   ZYE_0059   Ai210,php.eb-cre 2022-03-14       1 2022-03-14          1
# 4   ZYE_0060   Ai210,php.eb-cre 2022-03-23       2 2022-03-23          2
# 5    AB_0004  Ai210,php.eb-flpO 2021-03-30       1 2021-03-29          2
# 6   ZYE_0012  Ai210,php.eb-flpO 2020-10-16       5 2020-10-16          1
# 7   ZYE_0062   Ai210,php.eb-cre 2022-03-29       1 2022-03-29          1
# 8   ZYE_0043   Ai210,php.eb-cre 2021-09-13       1 2021-09-13          1
# 9    LK_0001          40 uL g7s 2021-04-07       1 2021-03-08          1
# 10   LK_0003       Ai210 triple 2021-04-06       1 2021-03-31          1
# 11  ZYE_0067           soma-g8m 2022-10-23       2 2022-10-23          2
# ...

# %% [markdown]
# ## Figure 1

# %%
save_folder = FIGURE_FOLDER / "Fig1"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals.plots.plotSpiralTimeSeries3d import plotSpiralTimeSeries3d

# plot example spiral time series & frame with optical flow
plotSpiralTimeSeries3d(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpiralTimeSeries import plotSpiralTimeSeries

# plot example spiral frame
plotSpiralTimeSeries(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpiralSequence3 import plotSpiralSequence3

# plot example spiral sequence
plotSpiralSequence3(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpiralDuration import plotSpiralDuration

# plot spiral duration ratio vs scrambled distribution
plotSpiralDuration(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpiralDensityAllSessions import plotSpiralDensityAllSessions

# plot spiral density map (combine all sessions)
plotSpiralDensityAllSessions(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpiralSpeedSummary import plotSpiralSpeedSummary

# plot spiral speeds for all spiral radii
plotSpiralSpeedSummary(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.makePressVideoExample import makePressVideoExample

# make press video example
makePressVideoExample(DATA_FOLDER, save_folder)
plt.show()
# Out:
# Saved video: D:\data\figures\Fig1\ZYE_0012_20201016_5_1681.44-1681.88.mp4 (151 frames)

# %% [markdown]
# ## Extended Data Fig. 1

# %%
save_folder = FIGURE_FOLDER / "FigS1"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals.plots.plotExampleOscillation import plotExampleOscillation

# plot example horizontal view and time series
plotExampleOscillation(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotPowerSpectrum4 import plotPowerSpectrum4

# plot mean power map across 15 sessions
plotPowerSpectrum4(T, DATA_FOLDER, save_folder)
plt.show()
# Out:
# C:\Users\dell\Documents\git\Ye-et-al-2023-python\spirals_py\spirals\plots\plotPowerSpectrum4.py:57: RuntimeWarning: invalid value encountered in divide
#   powerRatio = powerAlpha / powerTotal
# C:\Users\dell\Documents\git\Ye-et-al-2023-python\spirals_py\spirals\plots\plotPowerSpectrum4.py:61: RuntimeWarning: Mean of empty slice
#   powerRatio2 = np.nanmean(powerRatio1, axis=2)

# %%
from spirals_py.spirals.plots.plotExamplePowerSpectrum2 import plotExamplePowerSpectrum2

# plot example power spectrum
plotExamplePowerSpectrum2(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotPowerRatio3 import plotPowerRatio3

# plot power ratio
plotPowerRatio3(DATA_FOLDER, save_folder)
plt.show()
# Out:
# paired t-test RSP vs [VISp, SSp, MOs] p = [np.float32(2.0335185e-05), np.float32(0.0010143113), np.float32(0.6336003)]
# paired t-test SSp vs [VISp, RSP, MOs] p = [np.float32(0.010907287), np.float32(0.0010143113), np.float32(0.001421026)]
# corr(max_density, SSp power ratio): r = 0.8538, adjusted R^2 = 0.7082

# %%
from spirals_py.spirals.plots.plotPowerRatioRegression3 import plotPowerRatioRegression3

# plot power ratio regression
plotPowerRatioRegression3(T, DATA_FOLDER, save_folder)
plt.show()
# Out:
# ttest2 density p = 8.236e-09, power ratio p = 1.958e-05, alpha ratio p = 0.02857

# %%
from spirals_py.spirals.plots.plotExampleSpiral2b import plotExampleSpiral2b

# plot LK_0003 example spirals
plotExampleSpiral2b(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotExampleSpiralSpectrum2 import plotExampleSpiralSpectrum2

# plot LK_0003 power spectrum
plotExampleSpiralSpectrum2(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotExampleSpiral3b import plotExampleSpiral3b

# plot ZYE_0067 example spirals
plotExampleSpiral3b(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotExampleSpiralSpectrum3 import plotExampleSpiralSpectrum3

# plot ZYE_0067 power spectrum
plotExampleSpiralSpectrum3(T, DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Extended Data Fig. 2

# %%
save_folder = FIGURE_FOLDER / "FigS2"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals.plots.plotSpiralDetectionPipeline import plotSpiralDetectionPipeline

# plot spiral detection pipeline illustration
plotSpiralDetectionPipeline(T, DATA_FOLDER, save_folder)
plt.show()
# Out:
# C:\Users\dell\Documents\git\Ye-et-al-2023-python\spirals_py\spirals\plots\plotSpiralDetectionPipeline.py:105: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax2.scatter(cx - 1, cy - 1, s=24, c=greys[2 + 2 * rn], edgecolors="none")
# C:\Users\dell\Documents\git\Ye-et-al-2023-python\spirals_py\spirals\plots\plotSpiralDetectionPipeline.py:122: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## Extended Data Fig. 3

# %%
save_folder = FIGURE_FOLDER / "FigS3"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
freq = [2, 8]

from spirals_py.spirals.plots.plotExampleDataVsFft import plotExampleDataVsFft

# plot example epoch of data and 3d-fft
plotExampleDataVsFft(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotMapDataVsFftn import plotMapDataVsFftn

# plot density map (combine all sessions) for data and 3d-fft
plotMapDataVsFftn(DATA_FOLDER, save_folder, freq)
plt.show()

# %%
from spirals_py.spirals.plots.plotScatterDataVsFftn import plotScatterDataVsFftn

# plot peak density across sessions for data and 3d-fft
plotScatterDataVsFftn(T, DATA_FOLDER, save_folder, freq)
plt.show()

# %% [markdown]
# ## Extended Data Fig. 4

# %%
save_folder = FIGURE_FOLDER / "FigS4"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals.plots.plotLFPspirals import plotLFPspirals

# plot example spirals in cortical LFP
plotLFPspirals(DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Extended Data Fig. 5

# %%
save_folder = FIGURE_FOLDER / "FigS5"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
session_rows = list(range(6))  # MATLAB 1:6 (plot 6/15 sessions)

# %%
from spirals_py.spirals.plots.plotSpiralsBySession1 import plotSpiralsBySession1

# plot visual rf mapping by session
plotSpiralsBySession1(T, session_rows, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpiralsBySession2 import plotSpiralsBySession2

# plot spiral distribution by session
plotSpiralsBySession2(T, session_rows, DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Extended Data Fig. 6

# %%
save_folder = FIGURE_FOLDER / "FigS6"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals.plots.plotSpiralDensityByRadius import plotSpiralDensityByRadius

# plot spiral density maps across different radius
plotSpiralDensityByRadius(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpiralDensityByDuration import plotSpiralDensityByDuration

# plot spiral density maps across different durations
plotSpiralDensityByDuration(DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Extended Data Fig. 7

# %%
save_folder = FIGURE_FOLDER / "FigS7"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals.plots.plotExampleSpiralTrajectory import plotExampleSpiralTrajectory

# plot example grouped spiral sequences
plotExampleSpiralTrajectory(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpiralDirectionRatio2 import plotSpiralDirectionRatio2

# plot CCW spirals ratio across sessions
plotSpiralDirectionRatio2(T, DATA_FOLDER, save_folder)
plt.show()
# Out:
# paired t-test ccw ratio left vs right: p = 0.003022

# %%
from spirals_py.spirals.plots.plotSpiralDensitySessionsMeanSEM import plotSpiralDensitySessionsMeanSEM

# plot spiral density map mean and SEM across sessions
plotSpiralDensitySessionsMeanSEM(T, DATA_FOLDER, save_folder)
plt.show()
# Out:
# ttest2 peak density g7 vs g8: p = 8.236e-09 (g7 0.750+/-0.232, g8 3.504+/-0.628)

# %%
from spirals_py.spirals.plots.plotSpiralsSymmetryRatio import plotSpiralsSymmetryRatio

# plot spiral symmetry ratio across sessions
plotSpiralsSymmetryRatio(T, DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Extended Data Fig. 8

# %%
save_folder = FIGURE_FOLDER / "FigS8"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals.plots.plotSpiralSyncIndex import plotSpiralSyncIndex

# plot example time series and example frame index
plotSpiralSyncIndex(T, DATA_FOLDER, save_folder)
plt.show()
# Out:
# ZYE_0060_20220323_2: 0 spiral groups with duration >= 15 frames
# C:\Users\dell\Documents\git\Ye-et-al-2023-python\spirals_py\spirals\plots\plotSpiralSyncIndex.py:183: RuntimeWarning: invalid value encountered in divide
#   trace2d1 = trace2d1[:, :, trim:-trim] / mimgtransformed[:, :, None]
# C:\Users\dell\Documents\git\Ye-et-al-2023-python\spirals_py\spirals\plots\plotSpiralSyncIndex.py:185: RuntimeWarning: invalid value encountered in divide
#   traceAmp1 = traceAmp1[:, :, trim:-trim] / mimgtransformed[:, :, None]

# %%
from spirals_py.spirals.plots.plotMotionEnergyAmpX import plotMotionEnergyAmpX

# plot 2-8Hz amp vs motion energy relationship
plotMotionEnergyAmpX(T, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotAmpIndex import plotAmpIndex

# plot 2-8Hz amp vs index across sessions
plotAmpIndex(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotMotionEnergyIndex import plotMotionEnergyIndex

# plot motion energy vs index across sessions
plotMotionEnergyIndex(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotExamplePlaneWaveSeries2 import plotExamplePlaneWaveSeries2

# plot example plane wave
plotExamplePlaneWaveSeries2(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotWaveIndexAmp import plotWaveIndexAmp

# plot plane wave index vs 2-8 Hz amp
plotWaveIndexAmp(DATA_FOLDER, save_folder)
plt.show()
# Out:
# C:\Users\dell\anaconda3\envs\spirals-py\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
from spirals_py.spirals.plots.plotWaveRatio2 import plotWaveRatio2

# plot plane wave vs spiral wave ratio
plotWaveRatio2(DATA_FOLDER, save_folder)
plt.show()
# Out:
# paired t-test g8 plane vs spiral: p = 0.04203
# ttest2 plane g7 vs g8: p = 0.01017; spiral g7 vs g8: p = 8.236e-09

# %%
from spirals_py.spirals.plots.plotExamplePlaneWave import plotExamplePlaneWave

# plot example plane wave symmetry
plotExamplePlaneWave(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSymmetry4 import plotSymmetry4

# plot plane wave angle distribution across frames
plotSymmetry4(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotBorderPlaneWave import plotBorderPlaneWave

# plot plane wave angle distribution on the border
plotBorderPlaneWave(DATA_FOLDER, save_folder)
plt.show()
# Out:
# ROI mean flow: vx=-0.8749, vy=2.1496

# %% [markdown]
# ## Extended Data Fig. 9

# %%
save_folder = FIGURE_FOLDER / "FigS9"
save_folder.mkdir(parents=True, exist_ok=True)

# %%
from spirals_py.spirals.plots.plotSpiralSpeedExample import plotSpiralSpeedExample

# plot example spiral speed calculation illustration
plotSpiralSpeedExample(DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpeedForRadius import plotSpeedForRadius

# plot all spiral speeds at 50-pixel radius
plotSpeedForRadius(50, DATA_FOLDER, save_folder)
plt.show()

# %%
from spirals_py.spirals.plots.plotSpeedForRadius import plotSpeedForRadius

# plot all spiral speeds at 100-pixel radius
plotSpeedForRadius(100, DATA_FOLDER, save_folder)
plt.show()
