# %% [markdown]
# # pipeline6_task
#
# Python translation of `pipeline6_task.m` from Ye et al. 2023 (spirals): task preprocessing pipeline. Regenerates every `task/*.mat` file consumed by `notebooks/figure6_task.ipynb` from the raw data release.
#
# No figures are produced; progress is printed per mouse/session.

# %%
from pathlib import Path

from spirals_py.utils.paths import out_root

DATA_FOLDER = Path(r"D:\\data")  # MATLAB data release (inputs, read-only)
OUT_FOLDER = out_root()  # python outputs (D:\\data_python)

# %% [markdown]
# ## get psychometric curve and trial outcome

# %%
from spirals_py.task.preprocessing.getPsychometricCurve import getPsychometricCurve

save_folder = OUT_FOLDER / "task" / "psychometric_curve"
# get psychometric curves for all subjects
getPsychometricCurve(DATA_FOLDER, save_folder)
# Out:
# getPsychometricCurve: ZYE_0085 session 1/10
# getPsychometricCurve: ZYE_0085 session 2/10
# getPsychometricCurve: ZYE_0085 session 3/10
# getPsychometricCurve: ZYE_0085 session 4/10
# getPsychometricCurve: ZYE_0085 session 5/10
# getPsychometricCurve: ZYE_0085 session 6/10
# getPsychometricCurve: ZYE_0085 session 7/10
# getPsychometricCurve: ZYE_0085 session 8/10
# getPsychometricCurve: ZYE_0085 session 9/10
# getPsychometricCurve: ZYE_0085 session 10/10
# getPsychometricCurve: ZYE_0088 session 1/5
# getPsychometricCurve: ZYE_0088 session 2/5
# getPsychometricCurve: ZYE_0088 session 3/5
# getPsychometricCurve: ZYE_0088 session 4/5
# getPsychometricCurve: ZYE_0088 session 5/5
# getPsychometricCurve: ZYE_0090 session 1/9
# getPsychometricCurve: ZYE_0090 session 2/9
# getPsychometricCurve: ZYE_0090 session 3/9
# getPsychometricCurve: ZYE_0090 session 4/9
# getPsychometricCurve: ZYE_0090 session 5/9
# getPsychometricCurve: ZYE_0090 session 6/9
# getPsychometricCurve: ZYE_0090 session 7/9
# getPsychometricCurve: ZYE_0090 session 8/9
# getPsychometricCurve: ZYE_0090 session 9/9
# getPsychometricCurve: ZYE_0091 session 1/11
# getPsychometricCurve: ZYE_0091 session 2/11
# getPsychometricCurve: ZYE_0091 session 3/11
# getPsychometricCurve: ZYE_0091 session 4/11
# getPsychometricCurve: ZYE_0091 session 5/11
# getPsychometricCurve: ZYE_0091 session 6/11
# getPsychometricCurve: ZYE_0091 session 7/11
# getPsychometricCurve: ZYE_0091 session 8/11
# getPsychometricCurve: ZYE_0091 session 9/11
# getPsychometricCurve: ZYE_0091 session 10/11
# getPsychometricCurve: ZYE_0091 session 11/11

# %%
from spirals_py.task.preprocessing.getTaskTrialOutcome import getTaskTrialOutcome

save_folder = OUT_FOLDER / "task" / "task_outcome"
# get task trial outcome for each trial
getTaskTrialOutcome(DATA_FOLDER, save_folder)

# %% [markdown]
# ## get mean maps for different trial types

# %%
from spirals_py.task.preprocessing.getMeanMapSession import getMeanMapSession

save_folder = OUT_FOLDER / "task" / "task_mean_maps"
# get mean map for all contrast and trial types across sessions
getMeanMapSession(DATA_FOLDER, save_folder)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 5
#       1 from spirals_py.task.preprocessing.getMeanMapSession import getMeanMapSession
#       2
#       3 save_folder = OUT_FOLDER / "task" / "task_mean_maps"
#       4 # get mean map for all contrast and trial types across sessions
# ----> 5 getMeanMapSession(DATA_FOLDER, save_folder)
#
# File ~\Documents\git\Ye-et-al-2023-python\spirals_py\task\preprocessing\getMeanMapSession.py:52, in getMeanMapSession(data_folder, save_folder)
#      48 T1 = load_task_sessions(data_folder, mn)
#      49 task_outcome = release_twin(
#      50     out_root() / "task" / "task_outcome", data_folder
#      51 )
# ---> 52 T_all = load_task_table(task_outcome / f"{mn}_task_outcome.mat", "T_all")
#      53 trial_all = load_task_table(task_outcome / f"{mn}_task_trial_ID.mat", "trial_all")
#      55 for label in labels:
#      56     # for each trial type, concatenate all trials across sessions
#
# File ~\Documents\git\Ye-et-al-2023-python\spirals_py\task\preprocessing\load_task_table.py:26, in load_task_table(path, varname)
#      13 """Adaptation: decode a MATLAB table saved in a v7.3 (HDF5) .mat file
#      14 (scipy.io.loadmat cannot read MATLAB tables/MCOS objects).
#      15
#    (...)     23 files of this dataset).
#      24 """
#      25 path = Path(path)
# ---> 26 with h5py.File(path, "r") as f:
#      27     if varname not in f:
#      28         raise KeyError(f"{varname} not found in {path}")
#
# File ~\anaconda3\envs\spirals-py\Lib\site-packages\h5py\_hl\files.py:555, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, track_times, **kwds)
#     546     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     547                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     548                      alignment_threshold=alignment_threshold,
#     549                      alignment_interval=alignment_interval,
#     550                      meta_block_size=meta_block_size,
#     551                      **kwds)
#     552     fcpl = make_fcpl(track_order=track_order, track_times=track_times,
#     553                      fs_strategy=fs_strategy, fs_persist=fs_persist,
#     554                      fs_threshold=fs_threshold, fs_page_size=fs_page_size)
# --> 555     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     557 if isinstance(libver, tuple):
#     558     self._libver = libver
#
# File ~\anaconda3\envs\spirals-py\Lib\site-packages\h5py\_hl\files.py:232, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     230     if swmr:
#     231         flags |= h5f.ACC_SWMR_READ
# --> 232     fid = h5f.open(name, flags, fapl=fapl)
#     233 elif mode == 'r+':
#     234     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
# ---> 54 'Could not get source, probably due dynamically evaluated source code.'
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
# ---> 55 'Could not get source, probably due dynamically evaluated source code.'
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
# --> 106 'Could not get source, probably due dynamically evaluated source code.'
#
# OSError: Unable to synchronously open file (file signature not found)

# %%
from spirals_py.task.preprocessing.getMeanMapsAll import getMeanMapsAll

save_folder = OUT_FOLDER / "task" / "task_mean_maps"
# average mean maps at [-2,2]s around stim onset for 3 trial types
getMeanMapsAll(DATA_FOLDER, save_folder)

# %% [markdown]
# ## get spirals for different trial types

# %%
from spirals_py.task.preprocessing.getCorrectSpiralDensity import getCorrectSpiralDensity

save_folder = OUT_FOLDER / "task" / "spirals"
getCorrectSpiralDensity(DATA_FOLDER, save_folder)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 4
#       1 from spirals_py.task.preprocessing.getCorrectSpiralDensity import getCorrectSpiralDensity
#       2
#       3 save_folder = OUT_FOLDER / "task" / "spirals"
# ----> 4 getCorrectSpiralDensity(DATA_FOLDER, save_folder)
#
# File ~\Documents\git\Ye-et-al-2023-python\spirals_py\task\preprocessing\getCorrectSpiralDensity.py:46, in getCorrectSpiralDensity(data_folder, save_folder)
#      44 for mn in TASK_MICE:
#      45     sort_file = spiral_folder / f"{mn}_spirals_task_sort.mat"
# ---> 46     spiral_all = load_mat_cell(sort_file, "spiral_all")
#      47     T_all = load_mat_table(sort_file, "T_all")
#      48     left = T_all.left_contrast.to_numpy()
#
# File ~\Documents\git\Ye-et-al-2023-python\spirals_py\utils\matio.py:258, in load_mat_cell(path, varname)
#     256 with h5py.File(path, "r") as f:
#     257     dset = f[varname]
# --> 258     if dset.attrs.get("MATLAB_empty", 0) == 1:
#     259         return np.empty(dset.shape[::-1], dtype=object)
#     260     refs = dset[()]
#
# File ~\Documents\git\Ye-et-al-2023-python\spirals_py\utils\matio.py:42, in is_v73(path)
#      40 def is_v73(path):
#      41     """True if *path* is a MATLAB v7.3 (HDF5) .mat file.
# ---> 42
#      43     Genuine MATLAB v7.3 files start with a 512-byte user block ("MATLAB
#      44     7.3 MAT-file...") with the HDF5 signature at offset 512; files
#      45     written by h5py carry the signature at offset 0.
#      46     """
#      47     with open(path, "rb") as fh:
#      48         head = fh.read(8)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\data_python\\task\\spirals\\ZYE_0085_spirals_task_sort.mat'

# %% [markdown]
# ## get phase and amplitude around stim onset in VISp

# %%
from spirals_py.task.preprocessing.getTaskOnsetPhase import getTaskOnsetPhase

save_folder = OUT_FOLDER / "task" / "spirals"

freq1 = [0.05, 2]
# get phase and amplitude around onset time
getTaskOnsetPhase(DATA_FOLDER, save_folder, freq1)

# %%
from spirals_py.task.preprocessing.getTaskOnsetPhase import getTaskOnsetPhase

save_folder = OUT_FOLDER / "task" / "spirals"

freq2 = [2, 8]
# get phase and amplitude around onset time
getTaskOnsetPhase(DATA_FOLDER, save_folder, freq2)

# %% [markdown]
# ## spirals during each trial

# %%
from spirals_py.task.preprocessing.getTaskSpirals import getTaskSpirals

save_folder = OUT_FOLDER / "task" / "spirals"
# task spirals at [-2,2]s around onset time in each trial
getTaskSpirals(DATA_FOLDER, save_folder)
# Out:
# getTaskSpirals:  10%|█         | 1/10 [00:07<01:11,  7.99s/it]
# getTaskSpirals: ZYE_0085_20240711_1 (1/10)
# getTaskSpirals:  20%|██        | 2/10 [00:11<00:43,  5.48s/it]
# getTaskSpirals: ZYE_0085_20240712_1 (2/10)
# getTaskSpirals:  30%|███       | 3/10 [00:14<00:28,  4.10s/it]
# getTaskSpirals: ZYE_0085_20240713_2 (3/10)
# getTaskSpirals:  40%|████      | 4/10 [00:21<00:31,  5.18s/it]
# getTaskSpirals: ZYE_0085_20240717_1 (4/10)
# getTaskSpirals:  50%|█████     | 5/10 [00:28<00:30,  6.06s/it]
# getTaskSpirals: ZYE_0085_20240723_1 (5/10)
# getTaskSpirals:  60%|██████    | 6/10 [00:35<00:25,  6.32s/it]
# getTaskSpirals: ZYE_0085_20240724_1 (6/10)
# getTaskSpirals:  70%|███████   | 7/10 [00:37<00:14,  4.91s/it]
# getTaskSpirals: ZYE_0085_20240725_1 (7/10)
# getTaskSpirals:  80%|████████  | 8/10 [00:41<00:09,  4.68s/it]
# getTaskSpirals: ZYE_0085_20240726_1 (8/10)
# getTaskSpirals:  90%|█████████ | 9/10 [00:46<00:04,  4.78s/it]
# getTaskSpirals: ZYE_0085_20240727_3 (9/10)
# getTaskSpirals: 100%|██████████| 10/10 [00:53<00:00,  5.33s/it]
# getTaskSpirals: ZYE_0085_20240728_1 (10/10)
# getTaskSpirals:  20%|██        | 1/5 [00:04<00:18,  4.60s/it]
# getTaskSpirals: ZYE_0088_20240709_1 (1/5)
# getTaskSpirals:  40%|████      | 2/5 [00:08<00:12,  4.17s/it]
# getTaskSpirals: ZYE_0088_20240710_1 (2/5)
# getTaskSpirals:  60%|██████    | 3/5 [00:10<00:05,  2.98s/it]
# getTaskSpirals: ZYE_0088_20240712_1 (3/5)
# getTaskSpirals:  80%|████████  | 4/5 [00:12<00:02,  2.95s/it]
# getTaskSpirals: ZYE_0088_20240713_2 (4/5)
# getTaskSpirals: 100%|██████████| 5/5 [00:17<00:00,  3.43s/it]
# getTaskSpirals: ZYE_0088_20240715_2 (5/5)
# getTaskSpirals:  11%|█         | 1/9 [00:03<00:27,  3.38s/it]
# getTaskSpirals: ZYE_0090_20240716_1 (1/9)
# getTaskSpirals:  22%|██▏       | 2/9 [00:07<00:27,  3.91s/it]
# getTaskSpirals: ZYE_0090_20240811_4 (2/9)
# getTaskSpirals:  33%|███▎      | 3/9 [00:12<00:25,  4.29s/it]
# getTaskSpirals: ZYE_0090_20240812_1 (3/9)
# getTaskSpirals:  44%|████▍     | 4/9 [00:16<00:21,  4.38s/it]
# getTaskSpirals: ZYE_0090_20240813_3 (4/9)
# getTaskSpirals:  56%|█████▌    | 5/9 [00:19<00:15,  3.83s/it]
# getTaskSpirals: ZYE_0090_20240815_1 (5/9)
# getTaskSpirals:  67%|██████▋   | 6/9 [00:22<00:10,  3.61s/it]
# getTaskSpirals: ZYE_0090_20240816_1 (6/9)
# getTaskSpirals:  78%|███████▊  | 7/9 [00:25<00:06,  3.32s/it]
# getTaskSpirals: ZYE_0090_20240818_3 (7/9)
# getTaskSpirals:  89%|████████▉ | 8/9 [00:29<00:03,  3.38s/it]
# getTaskSpirals: ZYE_0090_20240819_1 (8/9)
# getTaskSpirals: 100%|██████████| 9/9 [00:32<00:00,  3.63s/it]
# getTaskSpirals: ZYE_0090_20240820_1 (9/9)
# getTaskSpirals:   9%|▉         | 1/11 [00:03<00:31,  3.18s/it]
# getTaskSpirals: ZYE_0091_20240708_1 (1/11)
# getTaskSpirals:  18%|█▊        | 2/11 [00:07<00:34,  3.83s/it]
# getTaskSpirals: ZYE_0091_20240709_1 (2/11)
# getTaskSpirals:  27%|██▋       | 3/11 [00:12<00:33,  4.17s/it]
# getTaskSpirals: ZYE_0091_20240710_1 (3/11)
# getTaskSpirals:  36%|███▋      | 4/11 [00:18<00:36,  5.16s/it]
# getTaskSpirals: ZYE_0091_20240711_1 (4/11)
# getTaskSpirals:  45%|████▌     | 5/11 [00:22<00:26,  4.48s/it]
# getTaskSpirals: ZYE_0091_20240712_1 (5/11)
# getTaskSpirals:  55%|█████▍    | 6/11 [00:25<00:20,  4.10s/it]
# getTaskSpirals: ZYE_0091_20240713_1 (6/11)
# getTaskSpirals:  64%|██████▎   | 7/11 [00:29<00:16,  4.17s/it]
# getTaskSpirals: ZYE_0091_20240714_3 (7/11)
# getTaskSpirals:  73%|███████▎  | 8/11 [00:34<00:12,  4.24s/it]
# getTaskSpirals: ZYE_0091_20240715_1 (8/11)
# getTaskSpirals:  82%|████████▏ | 9/11 [00:38<00:08,  4.18s/it]
# getTaskSpirals: ZYE_0091_20240716_1 (9/11)
# getTaskSpirals:  91%|█████████ | 10/11 [00:43<00:04,  4.42s/it]
# getTaskSpirals: ZYE_0091_20240717_2 (10/11)
# getTaskSpirals: 100%|██████████| 11/11 [00:46<00:00,  4.24s/it]
# getTaskSpirals: ZYE_0091_20240728_1 (11/11)

# %%
from spirals_py.task.preprocessing.getPassiveSpirals import getPassiveSpirals

save_folder = OUT_FOLDER / "task" / "spirals"
# passive spirals at [-2,2]s around onset time in each trial
getPassiveSpirals(DATA_FOLDER, save_folder)

# %%
from spirals_py.task.preprocessing.getSprialCountByRadiusTime import getSprialCountByRadiusTime

save_folder = OUT_FOLDER / "task" / "spirals"
# sort task spirals by radius and time around stim onset
getSprialCountByRadiusTime(DATA_FOLDER, save_folder)

# %%
from spirals_py.task.preprocessing.getPassiveSpiralPrePost import getPassiveSpiralPrePost

save_folder = OUT_FOLDER / "task" / "spirals"
# concatenate all passive spirals before and after stim onset
getPassiveSpiralPrePost(DATA_FOLDER, save_folder)

# %%
from spirals_py.task.preprocessing.getCorrectSpiralPrePost import getCorrectSpiralPrePost

save_folder = OUT_FOLDER / "task" / "spirals"
# concatenate all task spirals before and after stim onset
getCorrectSpiralPrePost(DATA_FOLDER, save_folder)
