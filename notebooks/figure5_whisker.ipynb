# %% [markdown]
# # Figure 5 — whisker stimulation (translation of figure5_whisker.m)
#
# Main Fig. 5 (b–f) and Fig. S15a. Figures are saved under `D:\data\figures\Fig5` and `D:\data\figures\FigS15`.

# %%
from pathlib import Path

import matplotlib.pyplot as plt

from spirals_py.whisker.plots.plotWhiskerMeanMap import plotWhiskerMeanMap
from spirals_py.whisker.plots.plotWhiskerMeanTrace import plotWhiskerMeanTrace
from spirals_py.whisker.plots.plotDensityPrePost import plotDensityPrePost
from spirals_py.whisker.plots.plotSpiralRatePeriStimulus import plotSpiralRatePeriStimulus
from spirals_py.whisker.plots.plotWhiskerSingleTrials import plotWhiskerSingleTrials

DATA_FOLDER = Path(r"D:\data")
FIGURE_FOLDER = DATA_FOLDER / "figures"
CODE_FOLDER = Path(r"C:\Users\dell\Documents\git\Ye-et-al-2023-python")  # repo root containing data_plus/

# %% [markdown]
# ## Figure 5b — mean whisker-evoked maps across 5 mice

# %%
save_folder = FIGURE_FOLDER / "Fig5"
save_folder.mkdir(parents=True, exist_ok=True)
h5b = plotWhiskerMeanMap(DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Figure 5c — mean traces around SSp center

# %%
h5c = plotWhiskerMeanTrace(DATA_FOLDER, save_folder, CODE_FOLDER)
plt.show()

# %% [markdown]
# ## Figure 5d,f — spiral density pre/post stimulus and rotation-direction ratios

# %%
h5d, h5f = plotDensityPrePost(DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Figure 5e — spiral rate peri-stimulus

# %%
h5e = plotSpiralRatePeriStimulus(DATA_FOLDER, save_folder)
plt.show()

# %% [markdown]
# ## Figure S15a — example single trials with spirals

# %%
save_folder_s15 = FIGURE_FOLDER / "FigS15"
save_folder_s15.mkdir(parents=True, exist_ok=True)
hs15a = plotWhiskerSingleTrials(DATA_FOLDER, save_folder_s15)
plt.show()
