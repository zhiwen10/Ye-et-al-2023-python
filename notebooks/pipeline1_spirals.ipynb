# %% [markdown]
# # pipeline1_spirals
#
# Python translation of `pipeline1_spirals.m` from Ye et al. 2023 (spirals): spiral-wave preprocessing pipeline. Regenerates every `spirals/*.mat` and spirals CSV file consumed by `notebooks/figure1_spirals.ipynb` from the raw data release.
#
# Cells tagged `detection` run the (slow) spiral detection itself (~1 h/session) and are skipped by `tools/run_pipeline.py` unless `--run-detection` is given; downstream steps then fall back to the release detection outputs. No figures are produced; progress bars show per-session progress.

# %%
from pathlib import Path

from spirals_py.utils.paths import data_root, out_root

import pandas as pd

DATA_FOLDER = data_root()  # MATLAB data release (SPIRALS_DATA_ROOT overrides)
OUT_FOLDER = out_root()  # python outputs (SPIRALS_OUT_ROOT overrides)

# load session table
T = pd.read_excel(DATA_FOLDER / "tables" / "spiralSessions3.xlsx")

# %% [markdown]
# ## spiral detection algorithm

# %%
from spirals_py.spirals.preprocessing.getSpiralDetection import getSpiralDetection

save_folder = OUT_FOLDER / "spirals" / "spirals_raw"
# run time estimate: 1h for each session
getSpiralDetection(T, DATA_FOLDER, save_folder)

# %% [markdown]
# ## spatiotemporal clustering of spirals

# %%
from spirals_py.spirals.preprocessing.getSpiralGrouping import getSpiralGrouping

save_folder = OUT_FOLDER / "spirals" / "spirals_grouping"
# group spirals by spatiotemporal proximity
getSpiralGrouping(T, DATA_FOLDER, save_folder)

# %% [markdown]
# ## Figure 1d

# %%
from spirals_py.spirals.preprocessing.getSpiralGroupingScrambled import getSpiralGroupingScrambled

save_folder = OUT_FOLDER / "spirals" / "spirals_scrambled"
# spirals grouping in frame scrambled data, 10x
getSpiralGroupingScrambled(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpiralDurationRatio import getSpiralDurationRatio

save_folder = OUT_FOLDER / "spirals" / "spirals_duration"
# ratio calculation
getSpiralDurationRatio(T, DATA_FOLDER, save_folder)

# %% [markdown]
# ## Figure 1e, Extended Data Fig.7c,d

# %%
from spirals_py.spirals.preprocessing.getSpiralDensityMap import getSpiralDensityMap

save_folder = OUT_FOLDER / "spirals" / "spirals_density"
# calculate spiral density
getSpiralDensityMap(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpiralsDensityLine import getSpiralsDensityLine

save_folder = OUT_FOLDER / "spirals" / "spirals_density"
# calculate spiral density lines
getSpiralsDensityLine(T, DATA_FOLDER, save_folder)

# %% [markdown]
# ## Extended Data Fig.1c,d,e,f, revision

# %%
from spirals_py.spirals.preprocessing.getTaperPowerMap3 import getTaperPowerMap3

save_folder = OUT_FOLDER / "spirals" / "spirals_power_spectrum2"
# calculate tapered power spectrum
getTaperPowerMap3(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getExamplePixelTrace_005_8Hz import getExamplePixelTrace_005_8Hz

save_folder = OUT_FOLDER / "spirals" / "spirals_power_spectrum2"
getExamplePixelTrace_005_8Hz(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getPowerBandRatio import getPowerBandRatio

save_folder = OUT_FOLDER / "spirals" / "spirals_power_spectrum2"
getPowerBandRatio(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.setAlphaThreshold import setAlphaThreshold

save_folder = OUT_FOLDER / "spirals" / "spirals_power_spectrum2"
setAlphaThreshold(T, DATA_FOLDER, save_folder)

# %% [markdown]
# ## Extended Data Fig.3

# %%
from spirals_py.spirals.preprocessing.getSpiralDetectionFftnRaw import getSpiralDetectionFftnRaw

freq = [2, 8]
label1 = "control"
label2 = "fftn"

save_folder = OUT_FOLDER / "spirals" / "spirals_fftn"
# spiral detection in raw data
getSpiralDetectionFftnRaw(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpiralDetectionFftnPermute import getSpiralDetectionFftnPermute

# spiral detection in fftn data
getSpiralDetectionFftnPermute(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getFFTNSpiralsMap import getFFTNSpiralsMap

freq = [2, 8]
label1 = "control"
label2 = "fftn"

# variables also defined in the (skippable) detection cell above
save_folder = OUT_FOLDER / "spirals" / "spirals_fftn"
# spiral maps in raw data
getFFTNSpiralsMap(T, freq, label1, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getFFTNSpiralsStats import getFFTNSpiralsStats

save_folder = OUT_FOLDER / "spirals" / "spirals_fftn"
# spiral stats in raw data
getFFTNSpiralsStats(T, freq, label1, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getFFTNSpiralsMap import getFFTNSpiralsMap

# spiral maps in fftn data
getFFTNSpiralsMap(T, freq, label2, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getFFTNSpiralsStats import getFFTNSpiralsStats

save_folder = OUT_FOLDER / "spirals" / "spirals_fftn"
# spiral stats in fftn data
getFFTNSpiralsStats(T, freq, label2, DATA_FOLDER, save_folder)

# %% [markdown]
# ## Extended Data Fig.3 revision: different frequency bands

# %%
from spirals_py.spirals.preprocessing.getSpiralsGroup_freq import getSpiralsGroup_freq

save_folder = OUT_FOLDER / "spirals" / "spirals_freq" / "spirals_fftn"
getSpiralsGroup_freq(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpiralsScrambled_freq import getSpiralsScrambled_freq

save_folder = OUT_FOLDER / "spirals" / "spirals_freq" / "spirals_scrambled"
getSpiralsScrambled_freq(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getDurationFreq import getDurationFreq

save_folder = OUT_FOLDER / "spirals" / "spirals_freq" / "spirals_duration"
getDurationFreq(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpiralDensityLine_all import getSpiralDensityLine_all

save_folder = OUT_FOLDER / "spirals" / "spirals_freq" / "spirals_density_line"
getSpiralDensityLine_all(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpiralsFFTnFreq import getSpiralsFFTnFreq

save_folder = OUT_FOLDER / "spirals" / "spirals_fftn"
# fftn detection chains the slow detection drivers
getSpiralsFFTnFreq(T, DATA_FOLDER, save_folder)

# %% [markdown]
# ## Extended Data Fig.6

# %%
from spirals_py.spirals.preprocessing.getSpiralDensityByDuration import getSpiralDensityByDuration

save_folder = OUT_FOLDER / "spirals" / "spirals_density_duration"
# spiral maps across durations
getSpiralDensityByDuration(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpiralDensityByRadius import getSpiralDensityByRadius

save_folder = OUT_FOLDER / "spirals" / "spirals_density_radius"
# spiral maps across radius
getSpiralDensityByRadius(T, DATA_FOLDER, save_folder)

# %% [markdown]
# ## Extended Data Fig.8

# %%
from spirals_py.spirals.preprocessing.getMotionEnergyIndex import getMotionEnergyIndex

save_folder = OUT_FOLDER / "spirals" / "spirals_index"
# bin spirality index based on motion energy
getMotionEnergyIndex(DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getAmpIndex import getAmpIndex

# bin spirality index based on 2-8Hz amplitude
getAmpIndex(DATA_FOLDER, save_folder)

# %% [markdown]
# ## Extended Data Fig.9

# %%
from spirals_py.spirals.preprocessing.getSpiralSpeed import getSpiralSpeed

save_folder = OUT_FOLDER / "spirals" / "spirals_speed"
# calculate spiral speed for each session
getSpiralSpeed(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpiralSpeedConcat import getSpiralSpeedConcat

save_folder = OUT_FOLDER / "spirals" / "spirals_speed"
# sort spiral speed based on radius for each session
getSpiralSpeedConcat(T, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpeedForRadius import getSpeedForRadius

radius = 50
save_folder = OUT_FOLDER / "spirals" / "spirals_speed"
# get speed for all spirals with radius of 50 pixels
getSpeedForRadius(T, radius, DATA_FOLDER, save_folder)

# %%
from spirals_py.spirals.preprocessing.getSpeedForRadius import getSpeedForRadius

radius = 100
save_folder = OUT_FOLDER / "spirals" / "spirals_speed"
# get speed for all spirals with radius of 100 pixels
getSpeedForRadius(T, radius, DATA_FOLDER, save_folder)
